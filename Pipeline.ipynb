# %%
import pandas as pd

# %%
customers_df = pd.read_excel("ETL_Assignment.xlsx",sheet_name = "Customers")
customers_df
# Out:
#     customer_id first_name last_name                      email  \
# 0             1     Regina     Banks           kjones@petty.biz
# 1             2       Mark      Pena      mercedes42@warner.com
# 2             3     Amanda    Carney   ricardosimmons@gmail.com
# 3             4    Brandon       Lee  kelleycharles@hotmail.com
# 4             5    Theresa   Ramirez        amybrown@butler.biz
# ..          ...        ...       ...                        ...
# 95           96   Brittany     Lopez        ysanchez@duncan.com
# 96           97   Benjamin  Cantrell        crystal86@wells.com
# 97           98     Bailey     Jones   carrollcharles@yahoo.com
# 98           99       Adam   Perkins            uluna@smith.net
# 99          100    Patrick      Bond         daniel94@smith.net
#
#               phone_number          created_at
# 0         374.831.2327x000 2022-11-20 19:15:32
# 1    001-698-370-1197x3825 2025-02-08 03:18:03
# 2             946-520-9112 2022-06-28 09:04:15
# ...

# %%
customers_df.isnull().sum()
# Out:
# customer_id     0
# first_name      0
# last_name       0
# email           0
# phone_number    0
# created_at      0
# dtype: int64

# %%
Products_df = pd.read_excel("ETL_Assignment.xlsx",sheet_name = "Products")
Products_df
# Out:
#     product_id     product_name     category   price  stock_quantity  \
# 0            1       Money Wear         Toys  234.12             238
# 1            2      Remain Item       Sports  115.50             240
# 2            3      True Gadget  Electronics  107.63              90
# 3            4  Southern Gadget     Clothing  108.82             239
# 4            5    Resource Wear     Clothing  103.66             423
# ..         ...              ...          ...     ...             ...
# 95          96   Against Device        Books   66.85             244
# 96          97         All Wear         Toys  496.07             385
# 97          98   Include Gadget     Clothing  416.28             288
# 98          99   Address Device  Electronics  315.38             422
# 99         100        Hope Tool         Toys   78.27              60
#
#             created_at
# 0  2023-08-23 13:17:46
# 1  2024-06-17 08:50:24
# 2  2025-01-15 02:58:29
# 3  2022-05-27 14:34:01
# ...

# %%
Products_df.isnull().sum()
# Out:
# product_id        0
# product_name      0
# category          0
# price             0
# stock_quantity    0
# created_at        0
# dtype: int64

# %%
Orders_df = pd.read_excel("ETL_Assignment.xlsx",sheet_name = "Orders")
Orders_df
# Out:
#      order_id  customer_id          order_date  total_amount     status
# 0           1           82 2024-01-17 19:11:33        163.94  Delivered
# 1           2           10 2022-05-11 02:09:15        334.71    Shipped
# 2           3           74 2020-05-20 20:11:19        674.77  Cancelled
# 3           4           22 2024-08-01 06:28:08        995.61  Delivered
# 4           5           19 2022-09-01 10:24:57        747.65    Shipped
# ..        ...          ...                 ...           ...        ...
# 195       196           28 2024-02-17 10:04:28        773.95    Shipped
# 196       197           98 2022-08-07 21:36:46        871.39  Cancelled
# 197       198           36 2024-11-26 20:42:36        712.46    Shipped
# 198       199           86 2020-05-13 20:20:52        104.72  Delivered
# 199       200           29 2023-07-12 21:42:01         52.29    Pending
#
# [200 rows x 5 columns]

# %%
Orders_df.isnull().sum()
# Out:
# order_id        0
# customer_id     0
# order_date      0
# total_amount    0
# status          0
# dtype: int64

# %%
Payments_df = pd.read_excel("ETL_Assignment.xlsx",sheet_name = "Payments")
Payments_df
# Out:
#      payment_id  order_id    payment_method payment_status  \
# 0             1       197            PayPal      Completed
# 1             2       173     Bank Transfer      Completed
# 2             3       107        Debit Card      Completed
# 3             4       185       Credit Card        Pending
# 4             5       141  Cash On Delivery         Failed
# ..          ...       ...               ...            ...
# 195         196        31       Credit Card        Pending
# 196         197        79            PayPal       Refunded
# 197         198        77        Debit Card         Failed
# 198         199       190        Debit Card      Completed
# 199         200         6  Cash On Delivery        Pending
#
#            payment_date  amount_paid
# 0   2021-08-07 05:44:03       627.38
# 1   2022-03-01 11:16:15        46.76
# 2   2024-02-26 18:44:29       586.88
# 3   2022-01-25 22:34:56       293.61
# 4   2024-01-02 15:03:18       377.65
# ...

# %%
Orders_df.isnull().sum()
# Out:
# order_id        0
# customer_id     0
# order_date      0
# total_amount    0
# status          0
# dtype: int64

# %%
from sqlalchemy import create_engine

# Replace with your MySQL credentials
engine = create_engine("mysql+mysqlconnector://root:12345@localhost:3306/ecommerce_db")

# %%
customers_df.to_sql('customers', con=engine, index=False, if_exists='append')
# Out:
# 100

# %%
Products_df.to_sql('Products', con=engine, index=False, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mysql\connector\connection_cext.py:755, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     754         query = query.encode("utf-8")
# --> 755     self._cmysql.query(
#     756         query,
#     757         raw=raw,
#     758         buffered=buffered,
#     759         raw_as_string=raw_as_string,
#     760         query_attrs=self.query_attrs,
#     761     )
#     762 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Duplicate entry '1' for key 'products.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# ...

# %%
Orders_df.to_sql('orders', con=engine, index=False, if_exists='append')
# Out:
# 200

# %%
Payments_df.to_sql('payments', con=engine, index=False, if_exists='append')
# Out:
# 200

# %%
query = """SELECT product_name FROM Products
WHERE category = "Electronics";"""

# %%
pd.read_sql(query,engine)
# Out:
#         product_name
# 0        True Gadget
# 1      Shoulder Tool
# 2      Out Accessory
# 3         Break Wear
# 4          Cell Tool
# 5      Myself Device
# 6            Pm Tool
# 7          Away Wear
# 8        Much Gadget
# 9           Job Wear
# 10      Several Tool
# 11  Person Accessory
# 12         Girl Tool
# 13    Address Device

# %%
query = '''SELECT c.customer_id, COUNT(o.customer_id) FROM customers as c
JOIN orders as o ON c.customer_id = o.customer_id
GROUP BY c.customer_id;'''

# %%
pd.read_sql(query,engine)
# Out:
#     customer_id  COUNT(o.customer_id)
# 0             2                     3
# 1             3                     4
# 2             4                     2
# 3             5                     2
# 4             8                     2
# ..          ...                   ...
# 78           94                     2
# 79           95                     2
# 80           96                     3
# 81           97                     5
# 82           98                     3
#
# [83 rows x 2 columns]

# %%
query = """SELECT o.order_id, o.customer_id, c.first_name, c.last_name , o.status
FROM customers as c
JOIN orders as o ON c.customer_id = o.customer_id;"""

# %%
pd.read_sql(query,engine)
# Out:
#      order_id  customer_id first_name last_name     status
# 0           1           82     Thomas    Steele  Delivered
# 1           2           10      Carla     Young    Shipped
# 2           3           74      Shawn     Brown  Cancelled
# 3           4           22      Tammy      Byrd  Delivered
# 4           5           19     Robert   Gardner    Shipped
# ..        ...          ...        ...       ...        ...
# 195       196           28      Sarah      Mack    Shipped
# 196       197           98     Bailey     Jones  Cancelled
# 197       198           36       John      Webb    Shipped
# 198       199           86     Glenda   Sampson  Delivered
# 199       200           29      Keith     Huang    Pending
#
# [200 rows x 5 columns]

# %%
query = """SELECT c.customer_id, c.first_name, c.last_name, COUNT(o.customer_id) as total_orders
FROM customers as c
JOIN orders as o ON c.customer_id = o.customer_id
GROUP BY c.customer_id,c.first_name, c.last_name
HAVING total_orders > 3;"""

# %%
pd.read_sql(query,engine)
# Out:
#     customer_id first_name last_name  total_orders
# 0             3     Amanda    Carney             4
# 1            10      Carla     Young             4
# 2            12     Marcia   Hoffman             5
# 3            13     Sandra  Martinez             4
# 4            22      Tammy      Byrd             5
# 5            32       Greg     Moran             5
# 6            48  Stephanie    Chavez             4
# 7            49   Veronica  Williams             5
# 8            54     Latoya     Lopez             4
# 9            60     Andrew    Walker             4
# 10           79     Joseph     Myers             5
# 11           89    Melissa    Murray             4
# 12           97   Benjamin  Cantrell             5

# %%
query = """SELECT *, o.order_date,o.total_amount
FROM payments AS p
JOIN orders AS o ON p.order_id = o.order_id
WHERE p.payment_status = "Completed";"""

# %%
pd.read_sql(query,engine)
# Out:
#     payment_id  order_id    payment_method payment_status        payment_date  \
# 0            1       197            PayPal      Completed 2021-08-07 05:44:03
# 1            2       173     Bank Transfer      Completed 2022-03-01 11:16:15
# 2            3       107        Debit Card      Completed 2024-02-26 18:44:29
# 3           10        43            PayPal      Completed 2022-04-16 13:46:52
# 4           14       126            PayPal      Completed 2020-01-02 15:18:01
# 5           16       181       Credit Card      Completed 2022-10-24 20:48:54
# 6           21       183  Cash On Delivery      Completed 2024-12-03 10:51:45
# 7           30        12     Bank Transfer      Completed 2021-08-08 12:12:45
# 8           32        95  Cash On Delivery      Completed 2020-04-07 06:10:44
# 9           41        22     Bank Transfer      Completed 2022-09-06 02:30:17
# 10          47       119        Debit Card      Completed 2023-01-03 03:36:33
# ...

# %%
query = """SELECT c.customer_id, c.first_name, c.last_name, c.email, SUM(o.total_amount) total_spent
FROM customers AS c
JOIN orders AS o ON c.customer_id = o.customer_id
GROUP BY c.customer_id,c.first_name, c.last_name, c.email
ORDER BY total_spent DESC
LIMIT 5;"""

# %%
pd.read_sql(query,engine)
# Out:
#    customer_id first_name last_name                          email  \
# 0           12     Marcia   Hoffman             xmurillo@yahoo.com
# 1           22      Tammy      Byrd  williamsonsabrina@hotmail.com
# 2           97   Benjamin  Cantrell            crystal86@wells.com
# 3           10      Carla     Young                csoto@yahoo.com
# 4           49   Veronica  Williams            cobrien@hotmail.com
#
#    total_spent
# 0      3335.72
# 1      3323.19
# 2      3153.06
# 3      2557.67
# 4      2554.51

# %%
query = """SELECT p.category, COUNT(o.order_id) AS total_order_count
FROM products AS p
JOIN orders AS o ON p.product_id = o.product_id
GROUP BY p.category
ORDER BY  total_order_count DESC
LIMIT 1;"""

# %%
pd.read_sql(query,engine)
# Out:
#    category  total_order_count
# 0  Clothing                 38

# %%
query = """SELECT o.order_id, o.customer_id, o.total_amount, o.status, p.payment_status
FROM orders AS o
JOIN payments AS p ON p.order_id = o.order_id
WHERE p.payment_status != "Completed";"""

# %%
pd.read_sql(query,engine)
# Out:
#      order_id  customer_id  total_amount     status payment_status
# 0         185           58         31.87  Cancelled        Pending
# 1         141           75        236.26    Pending         Failed
# 2          70           27        877.00    Shipped         Failed
# 3          65           22        755.98  Cancelled         Failed
# 4          88           48         21.38    Shipped       Refunded
# ..        ...          ...           ...        ...            ...
# 145       114           66        993.50    Pending       Refunded
# 146        31           23         80.87  Cancelled        Pending
# 147        79           26        888.58    Pending       Refunded
# 148        77           10        549.57    Shipped         Failed
# 149         6           68        183.19    Pending        Pending
#
# [150 rows x 5 columns]

# %%
query = """SELECT c.customer_id, c.first_name, c.last_name, c.email,AVG(o.total_amount) AS average_orders
FROM customers AS c
JOIN orders AS o ON c.customer_id = o.customer_id
GROUP BY c.customer_id,c.first_name, c.last_name, c.email;"""

# %%
pd.read_sql(query,engine)
# Out:
#     customer_id first_name last_name                            email  \
# 0            82     Thomas    Steele    mckinneychristopher@adams.com
# 1            10      Carla     Young                  csoto@yahoo.com
# 2            74      Shawn     Brown           sheila54@henderson.com
# 3            22      Tammy      Byrd    williamsonsabrina@hotmail.com
# 4            19     Robert   Gardner    montgomeryelizabeth@yahoo.com
# ..          ...        ...       ...                              ...
# 78           20      Bobby    Oliver           beardsylvia@kelley.com
# 79           93     Brenda   Edwards       harrisalexander@flores.com
# 80           62    Chelsea    Flores           daviskathryn@yahoo.com
# 81           59      Emily    Garcia          mark05@collins-hart.org
# 82           78     Connie      Love  lararobert@atkinson-winters.biz
#
#     average_orders
# 0       192.415000
# 1       639.417500
# 2       576.756667
# 3       664.638000
# 4       747.650000
# ...

# %%
query = """SELECT payment_method, COUNT(payment_method) AS count
FROM payments
GROUP BY payment_method
ORDER BY count DESC
LIMIT 1;"""

# %%
pd.read_sql(query,engine)
# Out:
#      payment_method  count
# 0  Cash On Delivery     48

# %%
query = """SELECT (SUM(CASE WHEN status = 'Cancelled' THEN 1 ELSE 0 END) * 100 / COUNT(*)) AS percentage
FROM orders;"""

# %%
pd.read_sql(query,engine)
# Out:
#    percentage
# 0        22.0

# %%
query = """SELECT MONTH(order_date) AS month, COUNT(*)
FROM orders 
GROUP BY MONTH(order_date)
LIMIT 1;"""

# %%
pd.read_sql(query,engine)
# Out:
#    month  COUNT(*)
# 0      1        22
